# %% [markdown]
# <a href="https://colab.research.google.com/github/DevanshTomar188/HealthGuard/blob/main/Diabetes_Disease_Prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# DATA COLLECTION ANALYSIS
# PIMA DIABETES DATASET

# %%
#loading the diabetes dataset to a pandas Dataframe:
diabetes_dataset = pd.read_csv('/content/diabetes_prediction_dataset.csv')

# %%
#Printing the first 10 rows:
diabetes_dataset.head(10)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 5  Female  20.0             0              0           never  27.32
# 6  Female  44.0             0              0           never  19.31
# 7  Female  79.0             0              0         No Info  23.86
# 8    Male  42.0             0              0           never  33.64
# 9  Female  32.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# ...

# %%
# number of Rows and Columns in dataset
diabetes_dataset.shape
# Out:
# (100000, 9)

# %%
# getting the statistical measure of the data
diabetes_dataset.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
diabetes_dataset['diabetes'].value_counts()
# Out:
# 0    91500
# 1     8500
# Name: diabetes, dtype: int64

# %% [markdown]
# 0...Represents "-" Symtoms
# 1...Represent "+" Symtoms

# %%
diabetes_dataset.groupby('diabetes').mean()
# Out:
# <ipython-input-7-810a02caa753>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   diabetes_dataset.groupby('diabetes').mean()
#                 age  hypertension  heart_disease        bmi  HbA1c_level  \
# diabetes
# 0         40.115187      0.058984       0.029235  26.887163     5.396761
# 1         60.946588      0.245647       0.149059  31.988382     6.934953
#
#           blood_glucose_level
# diabetes
# 0                  132.852470
# 1                  194.094706

# %%
#seprating the data and labels
X = diabetes_dataset.drop(columns = 'diabetes' , axis=1)
Y =  diabetes_dataset['diabetes']

# %%
print(X)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
print(Y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %% [markdown]
# DATA STANDARDIZATION

# %%
scaler = StandardScaler()

# %%
label_encoder = LabelEncoder()
diabetes_dataset['gender'] = label_encoder.fit_transform(diabetes_dataset['gender'])

# %%
# Identify non-numeric values in the 'gender' column
non_numeric_values = diabetes_dataset['gender'].loc[diabetes_dataset['gender'].str.isnumeric() == False]
print(non_numeric_values)

# Handle non-numeric values, for example, by filling them with a placeholder or removing them
diabetes_dataset['gender'] = diabetes_dataset['gender'].str.replace('Female', '0')  # Replace 'Female' with 0
diabetes_dataset['gender'] = diabetes_dataset['gender'].astype(float)  # Convert the column to float
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-73cfa8cdcd7a> in <cell line: 2>()
#       1 # Identify non-numeric values in the 'gender' column
# ----> 2 non_numeric_values = diabetes_dataset['gender'].loc[diabetes_dataset['gender'].str.isnumeric() == False]
#       3 print(non_numeric_values)
#       4
#       5 # Handle non-numeric values, for example, by filling them with a placeholder or removing them
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
# ...

# %%
# Out:
# LabelEncoder()
